# %% [markdown]
# <a href="https://colab.research.google.com/github/nmacdonald347/NumericalMethodsNLP/blob/main/Euclidean_spaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# Euclidean spaces : exercises
# ======
#
# Implement the following functions with `numpy`

# %%
import numpy as np


def norm(x):
    """
    Args:
      x (np.array): vector
    Returns:
      float. the norm of x
    """
    # YOUR CODE HERE
    raise NotImplementedError()

def distance(x,y):
    """
    Args:
       x (np.array): vector
       y (np.array): vector
    Returns:
       float. the euclidean distance between x and y
    """
    # YOUR CODE HERE
    raise NotImplementedError()

def similarity(x,y):
    """
    Args:
       x (np.array): vector
       y (np.array): vector
    Returns:
	float. the cosine of the angle between x and y
    """
    # YOUR CODE HERE
    raise NotImplementedError()

def is_orthogonal(x,y):
    """
    Args:
       x (np.array): vector
       y (np.array): vector
    Returns:
	bool. True if x and y are orthogonal, False otherwise.
    """
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# Euclidean spaces
# ====

# %% [markdown]
# Use numpy or the functions you defined above to solve the following exercises.
# Check manually that your solutions are correct.

# %%
# Vectors and distances

x = np.array([-1,5,2])
y = np.array([3,1,1])

# Compute x + y
# YOUR CODE HERE
raise NotImplementedError()

# Compute x - y
# YOUR CODE HERE
raise NotImplementedError()

# Compute x / ||x||
# YOUR CODE HERE
raise NotImplementedError()

# Compute || 0.5(x-y)||
# YOUR CODE HERE
raise NotImplementedError()

# Compute || 0.5(x+y)||
# YOUR CODE HERE
raise NotImplementedError()

# Compute x - 2y
# YOUR CODE HERE
raise NotImplementedError()

# Does || x-y || = ||x|| - ||y|| ?
# YOUR CODE HERE
raise NotImplementedError()


# Does || x+y || = ||x|| + ||y|| ?
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Angles

#Compute the angle (in degrees) between x and y

x = np.array([5,1,-2])
y = np.array([4,-4,3])

# YOUR CODE HERE
raise NotImplementedError()

#Compute the angle (in degrees) between x and y
x = np.array([7,2,-10])
y = np.array([2,6,4])

# YOUR CODE HERE
raise NotImplementedError()


#Are x and y orthogonal ?

x = np.array([8,4,3])
y = np.array([-2,1,4])

# YOUR CODE HERE
raise NotImplementedError()

#Are x and y orthogonal ?

x = np.array([6,0,4])
y = np.array([0,2,-1])

# YOUR CODE HERE
raise NotImplementedError()

# Check Cauchy Schwarz is  true on the example:
x = np.array([2,1,4])
y = np.array([1,-2,0])

# YOUR CODE HERE
raise NotImplementedError()

#Also check that the triangle inequality is true
# YOUR CODE HERE
raise NotImplementedError()


# Check Cauchy Schwarz is  true on the example:
x = np.array([4,2,-1])
y = np.array([8,4,-2])

# YOUR CODE HERE
raise NotImplementedError()

#Also check that the triangle inequality is true
# YOUR CODE HERE
raise NotImplementedError()
